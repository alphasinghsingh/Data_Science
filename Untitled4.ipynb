# %% [markdown]
# <a href="https://colab.research.google.com/github/alphasinghsingh/Data_Science/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
8iiuitems = ("tv", "fridge", "wmachine", "shirts", "fans")
prices = (200, 300, 400, 200, 100)
discount = (10, 20, 30, 40, 20)

# -------------------------
# STEP 1 : Convert to lists
# -------------------------
items_list = list(items)
prices_list = list(prices)
discount_list = list(discount)

# -------------------------------------
# STEP 2 : All calculations on the lists
# -------------------------------------

total_bill = sum(prices_list)

discount_amounts_list = []
for i in range(len(prices_list)):
    dis_amt = prices_list[i] * discount_list[i] / 100
    discount_amounts_list.append(dis_amt)

total_discount = sum(discount_amounts_list)
payable_amount = total_bill - total_discount

# ------------------------------------------------
# STEP 3 : Convert lists → tuples for output display
# ------------------------------------------------
items_tuple = tuple(items_list)
prices_tuple = tuple(prices_list)
discount_tuple = tuple(discount_list)
discount_amounts_tuple = tuple(discount_amounts_list)

# -------------------------
# STEP 4 : Final output
# -------------------------
print("Items:", items_tuple)
print("Prices:", prices_tuple)
print("Discount %:", discount_tuple)
print("Discount Amounts:", discount_amounts_tuple)

print("\nTotal Bill =", total_bill)
print("Total Discount =", total_discount)
print("Final Payable Amount =", payable_amount)
# Out:
# Items: ('tv', 'fridge', 'wmachine', 'shirts', 'fans')
# Prices: (200, 300, 400, 200, 100)
# Discount %: (10, 20, 30, 40, 20)
# Discount Amounts: (20.0, 60.0, 120.0, 80.0, 20.0)
#
# Total Bill = 1200
# Total Discount = 300.0
# Final Payable Amount = 900.0

# %%
a=(5,20,25,30)
b=(26,5,6,2,3)
c=(3,2,5,1,6)
c=list(c)
average=0
n=len(a)
add=sum(a)
#print(sum)
average= add/n
print(average)
#if b%2==0 :
 # print("number is even")
#else:
 # print("number is odd")
for i in b:
 if i%2 != 0:
   print(i)
n=len(c)
product = 1
for i in c:
   product *=i

print(product)
# Out:
# 20.0
# 5
# 3
# 180

# %%
a=(20,5,100,75,85,125,83)
n=len(a)
for i in a:
  if i%5 ==0:
    print("\t",i)


for i in a:
  if ((i%5 ==0) and (i%20==0)):
    print(i)


for i in a :
  if ((i%5 ==0) or (i%20==0)):
    print("\t",i)

for i in a:
  if ((i%5==0) and (i%20==0) or (i%15==0)):
    print(i)
# Out:
# 	 20
# 	 5
# 	 100
# 	 75
# 	 85
# 	 125
# 20
# 100
# 	 20
# 	 5
# 	 100
# 	 75
# 	 85
# 	 125
# 20
# 100
# 75
