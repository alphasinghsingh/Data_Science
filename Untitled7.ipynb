# %% [markdown]
# <a href="https://colab.research.google.com/github/alphasinghsingh/Data_Science/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [16, 81, 256, 625]

result = sum(map(lambda x: x ** 0.25, numbers))

print(result)
# Out:
# 14.0
