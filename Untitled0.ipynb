# %% [markdown]
# <a href="https://colab.research.google.com/github/alphasinghsingh/Data_Science/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
str="rajupaisalaya"
print(str[4])
print(str[4 :9])
print(str[0:4])
print(str[9:13])
# Out:
# p
# paisa
# raju
# laya

# %%
name="abcd"
print(name[:3])
print(name[:2])
# Out:
# abc
# ab

# %%
name="maihoonkon"
print(name[3:7])
# Out:
# hoon

# %%
y="kaiseho"
print(y[2:5])
# Out:
# ise

# %%
z="kabhikabhi"
print(z[0:5])
# Out:
# kabhi

# %%
a="Humhihumhai"
print(a[-6:])
# Out:
# humhai

# %%
b="oyeraju"
print(b[2:5])
# Out:
# era

# %%
x="maihoonkaun"
y="k"
if y in x :
  print("\n k is available")
else :
 print("\n k is not available")
# Out:
#  k is available

# %%
str="tunemeragoldenwalachsmabecha"
print(str[8:18])
print(str[8:23])
print(str[0:8])
print
# Out:
# goldenwala
# goldenwalachsma
# tunemera
# e
