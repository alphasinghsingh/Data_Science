# %% [markdown]
# <a href="https://colab.research.google.com/github/alphasinghsingh/Data_Science/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
print("hello")
# Out:
# hello

# %%
print(" welcome")
# Out:
#  welcome

# %%
print("\n enter the price:")
item1 = int(input(" \n enter the price of pizza:"))
item2 = int(input(" \n enter the price of burger:"))
item3 = int(input(" \n enter the price of french fries:"))
total_price = item1 + item2 + item3
print("\n desired total price ="  ,total_price)
# Out:
#  enter the price:
#
#  enter the price of pizza:300
#
#  enter the price of burger:200
#
#  enter the price of french fries:400
#
#  desired total price = 900
